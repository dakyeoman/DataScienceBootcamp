# %% [markdown]
# ### 문제 1.
#
# 0	이상	정수로	이루어진	리스트	nums와	0	이상	정수	k	를	입력으로	받는다.
# 리스트의	원소를	둘씩 짝지으려고	하는데,	각각의	쌍의	합이	모두	k로	나누어지도록	짝을	지으려	한다.
#
# 가능하면	True, 불가능하면 False를 return하는 함수를 구현하시오.
# (리스트의 길이는 2이상 짝수이다)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def P1(nums: list, k: int) -> bool:

    ### Write code here ###

    
    return True
    
    ### End of your code ###

# %% [markdown]
# ### 문제 2.
#
# 0과	1로만	이루어진	리스트	nums를	입력으로	받는다.
#
# 0과	1의	개수가	같은	부분	리스트의	길이의 최대값을	return하는	함수를	구현하시오.
#
# 부분	리스트란, nums[i:j],   0≤i≤j≤len(nums)와 같이 리스트의 연속된 일부분을 뜻한다.
#
# 그러한 부분 리스트가 없으면 0을 return하면 된다.
#
# (리스트의 길이는 1 이상이다.)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def P2(nums: list) -> int:

    ### Write code here ###

    
    return 0
    
    ### End of your code ###
